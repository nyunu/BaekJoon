# %% [markdown]
# <a href="https://colab.research.google.com/github/nyunu/BaekJoon/blob/main/1598.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a, b = map(int, input().split())
a -= 1
b -= 1

width = abs((a // 4) - (b // 4))
height = abs((a % 4) - (b % 4))

print(width + height)
# Out:
# 11 33
# 8

# %% [markdown]
# ![KakaoTalk_20230202_150849461.jpg](data:image/jpeg;base64,...)
